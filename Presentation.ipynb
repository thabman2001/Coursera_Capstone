# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import json # library to handle JSON files
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents
# !conda install -c conda-forge beautifulsoup4 --yes
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
print('Block1: Success')

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
print('Block2: Success')


# import k-means from clustering stage
from sklearn.cluster import KMeans
print('Block3: Success')

# !conda install -c conda-forge folium=0.5.0 --yes
#import folium # map rendering library
# !pip install folium
import folium # map rendering library

# !conda update -n base -c defaults conda 
print('Block4: Success')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.11.8  |       ha878542_0         145 KB  conda-forge
#     certifi-2020.11.8          |   py36h5fab9bb_0         150 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     openssl-1.1.1h             |       h516909a_0         2.1 MB  conda-forge
#     beautifulsoup4-4.9.3       |     pyhb0f4dca_0          86 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     python_abi:      3.6-1_cp36m            conda-forge
#
# The following packages will be UPDATED:
#
#     beautifulsoup4:  4.7.1-py36_1                       --> 4.9.3-pyhb0f4dca_0       conda-forge
#     ca-certificates: 2020.10.14-0                       --> 2020.11.8-ha878542_0     conda-forge
#     certifi:         2020.6.20-pyhd3eb1b0_3             --> 2020.11.8-py36h5fab9bb_0 conda-forge
#     openssl:         1.1.1h-h7b6447c_0                  --> 1.1.1h-h516909a_0        conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# certifi-2020.11.8    | 150 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# openssl-1.1.1h       | 2.1 MB    | ##################################### | 100%
# beautifulsoup4-4.9.3 | 86 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0          conda-forge
#     geopy:         2.0.0-pyh9f0ad1d_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Block1: Success
# Block2: Success
# Block3: Success
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: branca in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2->folium) (1.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.11.8)
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.51.0                |     pyhd3eb1b0_0          66 KB
#     conda-package-handling-1.7.2|   py37h03888b9_0         977 KB
#     conda-4.9.2                |   py37h06a4308_0         3.1 MB
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     conda-package-handling: 1.7.2-py37h03888b9_0
#     tqdm:                   4.51.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#     conda:                  4.5.12-py37_0        --> 4.9.2-py37h06a4308_0
#
#
# Downloading and Extracting Packages
# tqdm-4.51.0          | 66 KB     | ##################################### | 100%
# conda-package-handli | 977 KB    | ##################################### | 100%
# conda-4.9.2          | 3.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Block4: Success

# %% [markdown]
# Aubrey Cordinates per Google 33.3043° N, 96.9861° W

# %%
# define the dataframe columns
column_names = ['City', 'Latitude', 'Longitude'] 

# instantiate the dataframe
AubreyBase = pd.DataFrame(columns=column_names)
AubreyBase
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude]
# Index: []

# %%
address = 'Aubrey, Tx'

geolocator = Nominatim(user_agent="thabman2001@yahoo.com")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Aubrey are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Aubrey are 33.31420850000001, -96.97563229497024.

# %%
AubreyBase = AubreyBase.append({'City': "Aubrey",
                                          'Latitude': latitude,
                                          'Longitude': longitude}, ignore_index=True)
AubreyBase
# Out:
#      City   Latitude  Longitude
# 0  Aubrey  33.314209 -96.975632

# %%
##Use geopy library to get the latitude and longitude values of Little Elm

# %%
# create map using latitude and longitude values
map_LE = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, city in zip(AubreyBase['Latitude'], AubreyBase['Longitude'], AubreyBase['City']):
    label = '{}, {}'.format(AubreyBase, city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=475,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.3,
                parse_html=False).add_to(map_LE)  
    
map_LE
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
##Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'SAOHEOWDGB1IEJ5R1BNR3NWVOGBSYWLQRXPXPFSRJ5UC5SO3' # your Foursquare ID
CLIENT_SECRET = 'HJQTJAA0Y5I3BS5BAOVHM51JK4EMXO0VNU1WBXPARX1HUKC3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SAOHEOWDGB1IEJ5R1BNR3NWVOGBSYWLQRXPXPFSRJ5UC5SO3
# CLIENT_SECRET:HJQTJAA0Y5I3BS5BAOVHM51JK4EMXO0VNU1WBXPARX1HUKC3

# %%
# type your answer here
LIMIT = 200 # limit of number of venues returned by Foursquare API
radius = 15000 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=SAOHEOWDGB1IEJ5R1BNR3NWVOGBSYWLQRXPXPFSRJ5UC5SO3&client_secret=HJQTJAA0Y5I3BS5BAOVHM51JK4EMXO0VNU1WBXPARX1HUKC3&v=20180605&ll=33.31420850000001,-96.97563229497024&radius=15000&limit=200'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fb68efa5111134f6bf417e2'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Aubrey',
#   'headerFullLocation': 'Aubrey',
#   'headerLocationGranularity': 'city',
#   'totalResults': 73,
#   'suggestedBounds': {'ne': {'lat': 33.44920863500014,
#     'lng': -96.81438696722928},
#    'sw': {'lat': 33.17920836499987, 'lng': -97.1368776227112}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6ba899d4c01ce018187525',
#        'name': "Kathy's Country Kitchen",
#        'location': {'address': 'US 377',
#         'lat': 33.30499605174548,
#         'lng': -96.97961665132291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.30499605174548,
#           'lng': -96.97961665132291}],
#         'distance': 1090,
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['US 377', 'Aubrey, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6ba899d4c01ce018187525-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5676f2ad498ed4177ca1e127',
#        'name': "Bebo's Cafe",
#        'location': {'address': 'US Hwy 377',
#         'lat': 33.324092,
#         'lng': -96.970534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.324092,
#           'lng': -96.970534}],
#         'distance': 1198,
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['US Hwy 377', 'Aubrey, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5676f2ad498ed4177ca1e127-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7c5c47f964a520b08e2fe3',
#        'name': 'SONIC Drive In',
#        'location': {'address': '924 S Highway 377',
#         'lat': 33.2925280340747,
#         'lng': -96.9860614911522,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2925280340747,
#           'lng': -96.9860614911522},
#          {'label': 'entrance', 'lat': 33.292581, 'lng': -96.985924}],
#         'distance': 2601,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['924 S Highway 377',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7c5c47f964a520b08e2fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51bcab71498e7a733520848b',
#        'name': 'Upper Park Cafe',
#        'location': {'address': '200 S Main St',
#         'lat': 33.303428000000004,
#         'lng': -96.98659599999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.303428000000004,
#           'lng': -96.98659599999999},
#          {'label': 'entrance', 'lat': 33.303557, 'lng': -96.986436}],
#         'distance': 1574,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['200 S Main St',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51bcab71498e7a733520848b-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb8add598c7ef3bc4463102',
#        'name': 'Moms On Main',
#        'location': {'address': '206 Main Street',
#         'lat': 33.30342879466755,
#         'lng': -96.98653645353326,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.30342879466755,
#           'lng': -96.98653645353326}],
#         'distance': 1571,
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['206 Main Street',
#          'Aubrey, TX',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb8add598c7ef3bc4463102-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe9a9885fbb713411e7167',
#        'name': 'Ray Roberts Lake State Park',
#        'location': {'address': '100 PW 4137',
#         'crossStreet': 'FM 455',
#         'lat': 33.37876931956014,
#         'lng': -97.02617286480823,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.37876931956014,
#           'lng': -97.02617286480823}],
#         'distance': 8587,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['100 PW 4137 (FM 455)',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d161941735',
#          'name': 'Lake',
#          'pluralName': 'Lakes',
#          'shortName': 'Lake',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe9a9885fbb713411e7167-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57e5cbd0498e872e0c74da14',
#        'name': 'Fortunata Winery',
#        'location': {'lat': 33.243343,
#         'lng': -96.96286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.243343,
#           'lng': -96.96286}],
#         'distance': 7977,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Aubrey, TX 76227', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2106638',
#         'url': 'https://www.grubhub.com/restaurant/fortunata-winery-2297-fm2931-aubrey/2106638?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2106638',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57e5cbd0498e872e0c74da14-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba6e735f964a520897639e3',
#        'name': 'Villa Grande',
#        'location': {'address': '26399 US Highway 380 E',
#         'crossStreet': 'US 380 and FM720',
#         'lat': 33.224712184581904,
#         'lng': -96.97842405534139,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.224712184581904,
#           'lng': -96.97842405534139}],
#         'distance': 9966,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['26399 US Highway 380 E (US 380 and FM720)',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1655795',
#         'url': 'https://www.grubhub.com/restaurant/villa-grande-mexican-restaurant-12000-us-380-aubrey/1655795?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1655795',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba6e735f964a520897639e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5800104238fa38b85777d113',
#        'name': 'Chick-fil-A',
#        'location': {'address': '11851 US Highway 380',
#         'crossStreet': 'Walmart Dr',
#         'lat': 33.2244873,
#         'lng': -96.9828262,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2244873,
#           'lng': -96.9828262}],
#         'distance': 10010,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Crossroads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11851 US Highway 380 (Walmart Dr)',
#          'Crossroads, TX 76227',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573550',
#          'name': 'Food Service',
#          'pluralName': 'Food Services',
#          'shortName': 'Food Service',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5800104238fa38b85777d113-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c014244cf3aa593a4b7ccb0',
#        'name': 'Sharkarosa Wildlife Ranch',
#        'location': {'address': '11670 Massey Rd',
#         'crossStreet': 'at FM 455',
#         'lat': 33.37707537129021,
#         'lng': -96.97003196261747,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.37707537129021,
#           'lng': -96.97003196261747},
#          {'label': 'entrance', 'lat': 33.377334, 'lng': -96.97009}],
#         'distance': 7017,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11670 Massey Rd (at FM 455)',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15b941735',
#          'name': 'Farm',
#          'pluralName': 'Farms',
#          'shortName': 'Farm',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/farm_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '116485432'}},
#       'referralId': 'e-0-4c014244cf3aa593a4b7ccb0-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b32d20bf964a5207e1425e3',
#        'name': 'Prairie House Restaurant',
#        'location': {'address': '10001 US Highway 380',
#         'lat': 33.22568523435832,
#         'lng': -96.98963650619787,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22568523435832,
#           'lng': -96.98963650619787}],
#         'distance': 9940,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Cross Roads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10001 US Highway 380',
#          'Cross Roads, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1879025',
#         'url': 'https://www.grubhub.com/restaurant/prairie-house-restaurant-10001-us-380-cross-roads/1879025?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1879025',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b32d20bf964a5207e1425e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527d6a7011d2e85d742f90a4',
#        'name': "Mom's Burgers & Wings",
#        'location': {'address': '26615 US Highway 380 E Ste 170',
#         'lat': 33.22239951761362,
#         'lng': -96.96205567613413,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22239951761362,
#           'lng': -96.96205567613413}],
#         'distance': 10297,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['26615 US Highway 380 E Ste 170',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2252444',
#         'url': 'https://www.grubhub.com/restaurant/moms-burgers-and-wings-26615-us-hwy-380-e-ste-170-aubrey/2252444?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2252444',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-527d6a7011d2e85d742f90a4-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d98b4410caaa143694ab3b3',
#        'name': 'Subway',
#        'location': {'address': '928 S Highway 377 Ste 100',
#         'lat': 33.2915601,
#         'lng': -96.9862001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2915601,
#           'lng': -96.9862001},
#          {'label': 'entrance', 'lat': 33.29151, 'lng': -96.986063}],
#         'distance': 2706,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['928 S Highway 377 Ste 100',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d98b4410caaa143694ab3b3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54679def498e6a5dab752ac7',
#        'name': "Fuzzy's Taco Shop",
#        'location': {'address': '11450 Hwy 380, Suite 160',
#         'crossStreet': 'FM 424',
#         'lat': 33.226081,
#         'lng': -96.986283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.226081,
#           'lng': -96.986283}],
#         'distance': 9860,
#         'postalCode': '76227',
#         'cc': 'US',
#         'neighborhood': 'Aubrey',
#         'city': 'Cross Roads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11450 Hwy 380, Suite 160 (FM 424)',
#          'Cross Roads, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54679def498e6a5dab752ac7-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db374f2fa8c350240cf4b80',
#        'name': 'Palios Pizza Cafe',
#        'location': {'address': '9900 US Highway 380',
#         'crossStreet': 'Fm 424',
#         'lat': 33.22641539603777,
#         'lng': -96.98999707835863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22641539603777,
#           'lng': -96.98999707835863}],
#         'distance': 9864,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Crossroads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9900 US Highway 380 (Fm 424)',
#          'Crossroads, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1447852',
#         'url': 'https://www.grubhub.com/restaurant/palios-pizza-cafe-9900-us-380-cross-roads/1447852?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1447852',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db374f2fa8c350240cf4b80-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5487629a498e9dcac1897c74',
#        'name': 'Starwood Cafe',
#        'location': {'address': '26735 US-380 E',
#         'lat': 33.2215549,
#         'lng': -96.9349513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2215549,
#           'lng': -96.9349513}],
#         'distance': 10987,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['26735 US-380 E',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2126765',
#         'url': 'https://www.grubhub.com/restaurant/starwood-cafe-26735-us-380-aubrey/2126765?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2126765',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '105031440'}},
#       'referralId': 'e-0-5487629a498e9dcac1897c74-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d02c0228620224bd6b39e40',
#        'name': "McAlister's Deli",
#        'location': {'address': 'Loop 288',
#         'lat': 33.22200341585189,
#         'lng': -96.976463500567,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22200341585189,
#           'lng': -96.976463500567}],
#         'distance': 10264,
#         'postalCode': '76210',
#         'cc': 'US',
#         'city': 'Denton',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Loop 288', 'Denton, TX 76210', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d02c0228620224bd6b39e40-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf2df4ccad2c9280a2b9a99',
#        'name': "Nick's Italian Restaurant",
#        'location': {'address': '1340 U. S. Highway 377',
#         'lat': 33.40945563851211,
#         'lng': -96.94213013503996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.40945563851211,
#           'lng': -96.94213013503996}],
#         'distance': 11050,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1340 U. S. Highway 377',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf2df4ccad2c9280a2b9a99-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5142072ae4b0145fc486da1f',
#        'name': 'Golden Chick',
#        'location': {'address': '26735 US-380 E',
#         'lat': 33.22147465119623,
#         'lng': -96.93470584124609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22147465119623,
#           'lng': -96.93470584124609}],
#         'distance': 11003,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Little Elm',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['26735 US-380 E',
#          'Little Elm, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5142072ae4b0145fc486da1f-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6994f2c946e21ef28eea8e',
#        'name': 'Dollar General',
#        'location': {'address': '990 S Highway 377',
#         'lat': 33.288209,
#         'lng': -96.986558,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.288209,
#           'lng': -96.986558},
#          {'label': 'entrance', 'lat': 33.288166, 'lng': -96.986351}],
#         'distance': 3067,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['990 S Highway 377',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c6994f2c946e21ef28eea8e-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '595d53769ec3991d3cbf3c3a',
#        'name': 'Kroger',
#        'location': {'address': '4650 W University Dr',
#         'crossStreet': 'Highway 380 And 423',
#         'lat': 33.22085443842357,
#         'lng': -96.87730001719666,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22085443842357,
#           'lng': -96.87730001719666}],
#         'distance': 13847,
#         'postalCode': '75078',
#         'cc': 'US',
#         'city': 'Prosper',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4650 W University Dr (Highway 380 And 423)',
#          'Prosper, TX 75078',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-595d53769ec3991d3cbf3c3a-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca7cc8476d3a093c5750f6b',
#        'name': 'Avondale Park',
#        'location': {'lat': 33.243121625662525,
#         'lng': -97.1072423874553,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.243121625662525,
#           'lng': -97.1072423874553}],
#         'distance': 14582,
#         'postalCode': '76209',
#         'cc': 'US',
#         'city': 'Denton',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Denton, TX 76209', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca7cc8476d3a093c5750f6b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '576db21e498e98ab8f4a5a8e',
#        'name': "Schlotzsky's",
#        'location': {'address': '11650 Highway 380 Suite #400',
#         'crossStreet': 'Walmart Dr',
#         'lat': 33.225717,
#         'lng': -96.984834,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.225717,
#           'lng': -96.984834}],
#         'distance': 9887,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Cross Roads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11650 Highway 380 Suite #400 (Walmart Dr)',
#          'Cross Roads, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-576db21e498e98ab8f4a5a8e-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e2c1b4867b6f4000735778a',
#        'name': 'Chick Fil-A',
#        'location': {'address': '4420 W University Dr',
#         'lat': 33.22074890136719,
#         'lng': -96.87319946289062,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22074890136719,
#           'lng': -96.87319946289062}],
#         'distance': 14111,
#         'postalCode': '75078',
#         'cc': 'US',
#         'city': 'Prosper',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4420 W University Dr',
#          'Prosper, TX 75078',
#          'United States']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5e2c1b4867b6f4000735778a-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '540cfd5d498e9f263163d634',
#        'name': "McDonald's",
#        'location': {'address': '11201 US Hwy 380',
#         'crossStreet': 'FM 720',
#         'lat': 33.22529366154892,
#         'lng': -96.98799316937306,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22529366154892,
#           'lng': -96.98799316937306}],
#         'distance': 9964,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Cross Roads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11201 US Hwy 380 (FM 720)',
#          'Cross Roads, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2094880',
#         'url': 'https://www.grubhub.com/restaurant/mcdonalds-11201-us-380-cross-roads/2094880?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2094880',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-540cfd5d498e9f263163d634-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a27136b780eee6e5b387ee6',
#        'name': 'Firehouse 52 Bar And Grill',
#        'location': {'address': '26781',
#         'crossStreet': 'US 380',
#         'lat': 33.2203,
#         'lng': -96.916145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2203,
#           'lng': -96.916145}],
#         'distance': 11829,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['26781 (US 380)',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a27136b780eee6e5b387ee6-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b512545a9e402002c1d9451',
#        'name': 'Mod Pizza',
#        'location': {'address': '4780 West University Drive',
#         'lat': 33.22017625,
#         'lng': -96.87956154,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.22017625,
#           'lng': -96.87956154}],
#         'distance': 13766,
#         'postalCode': '75078',
#         'cc': 'US',
#         'city': 'Prosper',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4780 West University Drive',
#          'Prosper, TX 75078',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '548110139'}},
#       'referralId': 'e-0-5b512545a9e402002c1d9451-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c48d60c6594be9a9e114424',
#        'name': 'CH Collins Athletic Complex',
#        'location': {'address': '1500 Long Rd',
#         'lat': 33.26190237746071,
#         'lng': -97.11337100145721,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.26190237746071,
#           'lng': -97.11337100145721}],
#         'distance': 14077,
#         'postalCode': '76207',
#         'cc': 'US',
#         'city': 'Denton',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1500 Long Rd',
#          'Denton, TX 76207',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d189941735',
#          'name': 'Football Stadium',
#          'pluralName': 'Football Stadiums',
#          'shortName': 'Football',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_football_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c48d60c6594be9a9e114424-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5223566011d2791155a4fc2e',
#        'name': 'Whataburger',
#        'location': {'address': '11250 US Hwy 380',
#         'crossStreet': 'Naylor Road',
#         'lat': 33.2264018,
#         'lng': -96.9877032,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2264018,
#           'lng': -96.9877032}],
#         'distance': 9838,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Cross Roads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11250 US Hwy 380 (Naylor Road)',
#          'Cross Roads, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5223566011d2791155a4fc2e-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ce41983b3d8e20039e0f1c9',
#        'name': 'Canes',
#        'location': {'address': '4760 W University Dr',
#         'crossStreet': '423',
#         'lat': 33.21962356567383,
#         'lng': -96.87904357910156,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.21962356567383,
#           'lng': -96.87904357910156}],
#         'distance': 13844,
#         'postalCode': '75078',
#         'cc': 'US',
#         'city': 'Prosper',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4760 W University Dr (423)',
#          'Prosper, TX 75078',
#          'United States']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ce41983b3d8e20039e0f1c9-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1ab54e55e4c9b619384823',
#        'name': 'Chicken Express',
#        'location': {'address': '926 S Highway 377',
#         'lat': 33.29193,
#         'lng': -96.986103,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.29193,
#           'lng': -96.986103},
#          {'label': 'entrance', 'lat': 33.291896, 'lng': -96.985999}],
#         'distance': 2664,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['926 S Highway 377',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1ab54e55e4c9b619384823-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c8c0f3ad41bb7002c92c72e',
#        'name': 'Panera Bread',
#        'location': {'lat': 33.219227,
#         'lng': -96.872895,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.219227,
#           'lng': -96.872895}],
#         'distance': 14255,
#         'postalCode': '75078',
#         'cc': 'US',
#         'city': 'Prosper',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Prosper, TX 75078', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2032774',
#         'url': 'https://www.grubhub.com/restaurant/panera-bread-4480-w-university-dr-prosper/2032774?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2032774',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c8c0f3ad41bb7002c92c72e-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b4b24f065211f002cb05cd8',
#        'name': 'Fuzzy’s Taco Shop-Prosper',
#        'location': {'lat': 33.2194173406699,
#         'lng': -96.8774544433274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2194173406699,
#           'lng': -96.8774544433274}],
#         'distance': 13958,
#         'postalCode': '75078',
#         'cc': 'US',
#         'city': 'Prosper',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Prosper, TX 75078', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b4b24f065211f002cb05cd8-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5772f5c4498ebc94a257bfe3',
#        'name': "It's A Burger",
#        'location': {'address': '26745 E. University Dr, Ste 102, E University Dr',
#         'lat': 33.221232,
#         'lng': -96.932322,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.221232,
#           'lng': -96.932322}],
#         'distance': 11107,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['26745 E. University Dr, Ste 102, E University Dr',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1655895',
#         'url': 'https://www.grubhub.com/restaurant/its-a-burger-26745-us-380-aubrey/1655895?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1655895',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5772f5c4498ebc94a257bfe3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b859aedf964a520276831e3',
#        'name': 'SONIC Drive In',
#        'location': {'address': '11601 US Highway 380',
#         'lat': 33.2248324084813,
#         'lng': -96.9854459166526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2248324084813,
#           'lng': -96.9854459166526}],
#         'distance': 9991,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Crossroads',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11601 US Highway 380',
#          'Crossroads, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b859aedf964a520276831e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9abb1ef964a520b3d035e3',
#        'name': 'SONIC Drive In',
#        'location': {'address': '300 S Highway 377',
#         'lat': 33.3938031670682,
#         'lng': -96.9474054949114,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.3938031670682,
#           'lng': -96.9474054949114},
#          {'label': 'entrance', 'lat': 33.393753, 'lng': -96.947276}],
#         'distance': 9240,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['300 S Highway 377',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9abb1ef964a520b3d035e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '516f12fb1d9f7d8fbbc27318',
#        'name': 'CVS pharmacy',
#        'location': {'address': 'Hwy 380 & Naylor Rd',
#         'crossStreet': 'Naylor Road',
#         'lat': 33.225640634684915,
#         'lng': -96.9886869457767,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.225640634684915,
#           'lng': -96.9886869457767}],
# ...
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50478a95e4b0deba9aba8082',
#        'name': 'SUBWAY',
#        'location': {'address': '2912 E University Dr Ste 100',
#         'lat': 33.23253654348,
#         'lng': -97.09189785210867,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.23253654348,
#           'lng': -97.09189785210867}],
#         'distance': 14133,
#         'postalCode': '76209',
#         'cc': 'US',
#         'city': 'Denton',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2912 E University Dr Ste 100',
#          'Denton, TX 76209',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1176104',
#         'url': 'https://www.grubhub.com/restaurant/subway-2912-e-university-dr-ste-100-denton/1176104?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1176104',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50478a95e4b0deba9aba8082-60'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc08bf7fa8c91858b3386d8',
#        'name': "Jerry's Beverage City",
#        'location': {'address': '801-899 Production Rd',
#         'lat': 33.408011116666664,
#         'lng': -96.94175003333334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.408011116666664,
#           'lng': -96.94175003333334},
#          {'label': 'entrance', 'lat': 33.407992, 'lng': -96.941905}],
#         'distance': 10906,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['801-899 Production Rd',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc08bf7fa8c91858b3386d8-61'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2ccc7462e144b5d3bb41e2',
#        'name': "Church's Chicken",
#        'location': {'address': '1800 N Highway 377',
#         'lat': 33.41350325509116,
#         'lng': -96.94132799617024,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.41350325509116,
#           'lng': -96.94132799617024}],
#         'distance': 11504,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1800 N Highway 377',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e2ccc7462e144b5d3bb41e2-62'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aec644ff964a5209ec621e3',
#        'name': 'Denton Natatorium',
#        'location': {'address': '2400 Long Rd',
#         'lat': 33.26232413493846,
#         'lng': -97.10811394973948,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.26232413493846,
#           'lng': -97.10811394973948}],
#         'distance': 13613,
#         'postalCode': '76207',
#         'cc': 'US',
#         'city': 'Denton',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2400 Long Rd',
#          'Denton, TX 76207',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aec644ff964a5209ec621e3-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ef4cd020aaf6577fe3a71cb',
#        'name': 'Taco Bell',
#        'location': {'address': '928 U.S. 377 #210',
#         'lat': 33.29132,
#         'lng': -96.98617800000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.29132,
#           'lng': -96.98617800000001},
#          {'label': 'entrance', 'lat': 33.29151, 'lng': -96.986063}],
#         'distance': 2730,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['928 U.S. 377 #210',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ef4cd020aaf6577fe3a71cb-64'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55e3f665498e164f0728b940',
#        'name': 'Texas-Tulips, LLC',
#        'location': {'address': '10656 Farm to Market Road 2931',
#         'lat': 33.34184609,
#         'lng': -96.92991743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.34184609,
#           'lng': -96.92991743}],
#         'distance': 5248,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10656 Farm to Market Road 2931',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4eb1c0253b7b52c0e1adc2e9',
#          'name': 'Garden Center',
#          'pluralName': 'Garden Centers',
#          'shortName': 'Garden Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/gardencenter_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '438497745'}},
#       'referralId': 'e-0-55e3f665498e164f0728b940-65'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f565935e4b005c48029e4ac',
#        'name': "McDonald's",
#        'location': {'address': '1226-1230 S US 377',
#         'lat': 33.38270280867586,
#         'lng': -96.96036586410406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.38270280867586,
#           'lng': -96.96036586410406}],
#         'distance': 7755,
#         'postalCode': '76258',
#         'cc': 'US',
#         'city': 'Pilot Point',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1226-1230 S US 377',
#          'Pilot Point, TX 76258',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f565935e4b005c48029e4ac-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb7e9db314e952101eb479d',
#        'name': 'SONIC Drive In',
#        'location': {'address': '2131 E University Dr',
#         'lat': 33.2366284,
#         'lng': -97.1047545,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2366284,
#           'lng': -97.1047545},
#          {'label': 'entrance', 'lat': 33.236445, 'lng': -97.104708}],
#         'distance': 14798,
#         'postalCode': '76209',
#         'cc': 'US',
#         'city': 'Denton',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2131 E University Dr',
#          'Denton, TX 76209',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb7e9db314e952101eb479d-67'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a2994cc4940bc75408c20bf',
#        'name': 'Beazer Homes Sutton Fields',
#        'location': {'address': '6508 Farndon Drive',
#         'lat': 33.2661306,
#         'lng': -96.89099689999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.2661306,
#           'lng': -96.89099689999999}],
#         'distance': 9521,
#         'postalCode': '75009',
#         'cc': 'US',
#         'city': 'Celina',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6508 Farndon Drive',
#          'Celina, TX 75009',
#          'United States']},
#        'categories': [{'id': '545419b1498ea6ccd0202f58',
#          'name': 'Home Service',
#          'pluralName': 'Home Services & Repairs',
#          'shortName': 'Home Services',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a2994cc4940bc75408c20bf-68'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c48c6056f1420a1f596b754',
#        'name': 'Denton Water Works',
#        'location': {'lat': 33.26189214262498,
#         'lng': -97.1086509727338,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.26189214262498,
#           'lng': -97.1086509727338}],
#         'distance': 13679,
#         'postalCode': '76207',
#         'cc': 'US',
#         'city': 'Denton',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Denton, TX 76207', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c48c6056f1420a1f596b754-69'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a4c4a5fea1e4412306bf8a1',
#        'name': 'Winn Ridge by Pulte Homes',
#        'location': {'address': '2921 Aslynn Cir',
#         'lat': 33.254273,
#         'lng': -96.8966459,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.254273,
#           'lng': -96.8966459}],
#         'distance': 9926,
#         'postalCode': '76227',
#         'cc': 'US',
#         'city': 'Aubrey',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2921 Aslynn Cir',
#          'Aubrey, TX 76227',
#          'United States']},
#        'categories': [{'id': '4d954b06a243a5684965b473',
#          'name': 'Residential Building (Apartment / Condo)',
#          'pluralName': 'Residential Buildings (Apartments / Condos)',
#          'shortName': 'Residential',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a4c4a5fea1e4412306bf8a1-70'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5583f80d498ed2615ace267e',
#        'name': 'Jerry Cassel',
#        'location': {'lat': 33.33970700424026,
#         'lng': -96.844482421875,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.33970700424026,
#           'lng': -96.844482421875}],
#         'distance': 12524,
#         'postalCode': '76140',
#         'cc': 'US',
#         'city': 'Fort Worth',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Fort Worth, TX 76140', 'United States']},
#        'categories': [{'id': '545419b1498ea6ccd0202f58',
#          'name': 'Home Service',
#          'pluralName': 'Home Services & Repairs',
#          'shortName': 'Home Services',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5583f80d498ed2615ace267e-71'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6fc45d71d3a14346eb4050',
#        'name': 'Lake Ray Roberts Johnson Branch Unit State Park',
#        'location': {'address': 'Unnamed Rd',
#         'lat': 33.4183652120822,
#         'lng': -97.05244107553885,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.4183652120822,
#           'lng': -97.05244107553885}],
#         'distance': 13617,
#         'postalCode': '76272',
#         'cc': 'US',
#         'city': 'Valley View',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Unnamed Rd',
#          'Valley View, TX 76272',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d161941735',
#          'name': 'Lake',
#          'pluralName': 'Lakes',
#          'shortName': 'Lake',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6fc45d71d3a14346eb4050-72'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                       name            categories        lat        lng
# 0  Kathy's Country Kitchen                  Café  33.304996 -96.979617
# 1              Bebo's Cafe   American Restaurant  33.324092 -96.970534
# 2           SONIC Drive In  Fast Food Restaurant  33.292528 -96.986061
# 3          Upper Park Cafe                  Café  33.303428 -96.986596
# 4             Moms On Main   American Restaurant  33.303429 -96.986536

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 73 venues were returned by Foursquare.

# %%
Frisco_address = 'Frisco, Tx'

geolocator = Nominatim(user_agent="thabman2001@yahoo.com")
Frisco_location = geolocator.geocode(Frisco_address)
Frisco_latitude = Frisco_location.latitude
Frisco_longitude = Frisco_location.longitude
print('The geograpical coordinate of Frisco are {}, {}.'.format(Frisco_latitude,Frisco_longitude))
# Out:
# The geograpical coordinate of Frisco are 33.1506744, -96.8236116.

# %%
# define the dataframe columns
Frisco_column_names = ['City', 'Latitude', 'Longitude'] 

# instantiate the dataframe
Frisco_Base = pd.DataFrame(columns=Frisco_column_names)
Frisco_Base = Frisco_Base.append({'City': "Frisco",
                                          'Latitude': Frisco_latitude,
                                          'Longitude': Frisco_longitude}, ignore_index=True)
Frisco_Base
# Out:
#      City   Latitude  Longitude
# 0  Frisco  33.150674 -96.823612

# %%
# create map using latitude and longitude values
map_Frisco = folium.Map(location=[Frisco_latitude, Frisco_longitude], zoom_start=13)

# add markers to map
for lat, lng, city in zip(Frisco_Base['Latitude'], Frisco_Base['Longitude'], Frisco_Base['City']):
    label = '{}, {}'.format(Frisco_Base, city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=475,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.3,
                parse_html=False).add_to(map_Frisco)  
    
map_Frisco
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# type your answer here
LIMIT1 = 200 # limit of number of venues returned by Foursquare API
radius1 = 15000 # define radius
url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    Frisco_latitude, 
    Frisco_longitude, 
    radius1, 
    LIMIT1)
url1 # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=SAOHEOWDGB1IEJ5R1BNR3NWVOGBSYWLQRXPXPFSRJ5UC5SO3&client_secret=HJQTJAA0Y5I3BS5BAOVHM51JK4EMXO0VNU1WBXPARX1HUKC3&v=20180605&ll=33.1506744,-96.8236116&radius=15000&limit=200'

# %%
results1 = requests.get(url1).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '5fb68ffed91d7d1d4980e25c'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Frisco',
#   'headerFullLocation': 'Frisco',
#   'headerLocationGranularity': 'city',
#   'totalResults': 231,
#   'suggestedBounds': {'ne': {'lat': 33.28567453500013,
#     'lng': -96.66266752771442},
#    'sw': {'lat': 33.015674264999866, 'lng': -96.9845556722856}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a6d2bd4f964a520a3d21fe3',
#        'name': "Babe's Chicken Dinner House",
#        'location': {'address': '6475 Page Rd',
#         'crossStreet': 'at John W Elliott Dr',
#         'lat': 33.14903143006786,
#         'lng': -96.83044639312995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.14903143006786,
#           'lng': -96.83044639312995},
#          {'label': 'entrance', 'lat': 33.148794, 'lng': -96.830338}],
#         'distance': 662,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6475 Page Rd (at John W Elliott Dr)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a6d2bd4f964a520a3d21fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b671b8af964a5200b3b2be3',
#        'name': "Mariana's Taco Shop",
#        'location': {'address': '8981 5th St',
#         'crossStreet': '4th',
#         'lat': 33.15136735032508,
#         'lng': -96.82400107383728,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15136735032508,
#           'lng': -96.82400107383728},
#          {'label': 'entrance', 'lat': 33.151358, 'lng': -96.823845}],
#         'distance': 85,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8981 5th St (4th)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1652660',
#         'url': 'https://www.grubhub.com/restaurant/marianas-taco-shop-8981-5th-street-frisco/1652660?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1652660',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b671b8af964a5200b3b2be3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b9ddbf964a520b9122ce3',
#        'name': 'Frisco Public Library',
#        'location': {'address': '6101 Frisco Square Blvd',
#         'lat': 33.15018204719045,
#         'lng': -96.83420925447962,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15018204719045,
#           'lng': -96.83420925447962}],
#         'distance': 989,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6101 Frisco Square Blvd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12f941735',
#          'name': 'Library',
#          'pluralName': 'Libraries',
#          'shortName': 'Library',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33512466'}},
#       'referralId': 'e-0-4b6b9ddbf964a520b9122ce3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7853aef964a520abc52ee3',
#        'name': 'Frisco Commons',
#        'location': {'address': '8000 McKinney Rd',
#         'crossStreet': 'McKinney Road & North County Road',
#         'lat': 33.153425655796255,
#         'lng': -96.81393362705032,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.153425655796255,
#           'lng': -96.81393362705032}],
#         'distance': 952,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8000 McKinney Rd (McKinney Road & North County Road)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7853aef964a520abc52ee3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aabe50ff964a520be5a20e3',
#        'name': '5th Street Patio Cafe',
#        'location': {'address': '8621 5th St',
#         'lat': 33.14781296825269,
#         'lng': -96.82479743603565,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.14781296825269,
#           'lng': -96.82479743603565},
#          {'label': 'entrance', 'lat': 33.147731, 'lng': -96.82473}],
#         'distance': 337,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8621 5th St',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1631454',
#         'url': 'https://www.grubhub.com/restaurant/5th-street-patio-cafe-8621-5th-street-frisco/1631454?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631454',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aabe50ff964a520be5a20e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57f69208498e064cc2dca6a7',
#        'name': 'Frisco Rail Yard',
#        'location': {'address': '9040 1st St',
#         'lat': 33.15218556870127,
#         'lng': -96.82801581173915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15218556870127,
#           'lng': -96.82801581173915}],
#         'distance': 443,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9040 1st St',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57f69208498e064cc2dca6a7-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589a532caf5c141e6cca4711',
#        'name': 'ILoveKickboxing.com - Frisco, TX',
#        'location': {'address': '8845 Gary Burns Dr #150',
#         'lat': 33.14925596092092,
#         'lng': -96.80598397303409,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.14925596092092,
#           'lng': -96.80598397303409}],
#         'distance': 1650,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8845 Gary Burns Dr #150',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589a532caf5c141e6cca4711-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514a4113e4b0dd976e2585c6',
#        'name': 'Hope Park',
#        'location': {'address': '8000 McKinney Rd',
#         'lat': 33.15378312342159,
#         'lng': -96.81357214208845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15378312342159,
#           'lng': -96.81357214208845}],
#         'distance': 997,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8000 McKinney Rd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514a4113e4b0dd976e2585c6-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b15502df964a5200db023e3',
#        'name': 'Toyota Stadium',
#        'location': {'address': '9200 World Cup Way',
#         'crossStreet': 'at Main & Frisco Sts',
#         'lat': 33.1543410998625,
#         'lng': -96.83544276134788,
#         'distance': 1175,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9200 World Cup Way (at Main & Frisco Sts)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d188941735',
#          'name': 'Soccer Stadium',
#          'pluralName': 'Soccer Stadiums',
#          'shortName': 'Soccer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32682910'}},
#       'referralId': 'e-0-4b15502df964a5200db023e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4e41b0e4b0577d81b03477',
#        'name': 'En Fuego Tobacco Shop',
#        'location': {'address': '6190 Frisco Square Blvd',
#         'lat': 33.15126384542201,
#         'lng': -96.83395329648663,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15126384542201,
#           'lng': -96.83395329648663},
#          {'label': 'entrance', 'lat': 33.151145, 'lng': -96.834041}],
#         'distance': 966,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6190 Frisco Square Blvd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123951735',
#          'name': 'Smoke Shop',
#          'pluralName': 'Smoke Shops',
#          'shortName': 'Smoke Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4e41b0e4b0577d81b03477-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e90254498eaa4c89365594',
#        'name': 'Chick-fil-A',
#        'location': {'address': '8875 Preston Rd',
#         'lat': 33.149233,
#         'lng': -96.8051742,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.149233,
#           'lng': -96.8051742},
#          {'label': 'entrance', 'lat': 33.149181, 'lng': -96.804949}],
#         'distance': 1725,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8875 Preston Rd',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2041742',
#         'url': 'https://www.grubhub.com/restaurant/chick-fil-a-8875-preston-rd-frisco/2041742?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2041742',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e90254498eaa4c89365594-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e6ec798bbd274dcb6e7897',
#        'name': 'Freebirds World Burrito',
#        'location': {'address': '5170 Main Street, Ste. 900',
#         'lat': 33.153359194948,
#         'lng': -96.84175997972488,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.153359194948,
#           'lng': -96.84175997972488},
#          {'label': 'entrance', 'lat': 33.153279, 'lng': -96.841884}],
#         'distance': 1717,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5170 Main Street, Ste. 900',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1943088',
#         'url': 'https://www.grubhub.com/restaurant/freebirds-world-burrito-5170-main-st-frisco/1943088?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1943088',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51e6ec798bbd274dcb6e7897-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53653eca498e7f014d89e43c',
#        'name': 'Hutchins BBQ',
#        'location': {'address': '9225 Preston Rd',
#         'lat': 33.15459315172794,
#         'lng': -96.80469570495437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15459315172794,
#           'lng': -96.80469570495437},
#          {'label': 'entrance', 'lat': 33.154578, 'lng': -96.804755}],
#         'distance': 1816,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9225 Preston Rd',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1632830',
#         'url': 'https://www.grubhub.com/restaurant/hutchins-bbq-9225-preston-road-frisco/1632830?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1632830',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53653eca498e7f014d89e43c-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c75b662ff1fb60c0422f7a7',
#        'name': 'FC Dallas Soccer Fields',
#        'location': {'lat': 33.15691839374224,
#         'lng': -96.83651578742497,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15691839374224,
#           'lng': -96.83651578742497}],
#         'distance': 1389,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Frisco, TX 75034', 'United States']},
#        'categories': [{'id': '4cce455aebf7b749d5e191f5',
#          'name': 'Soccer Field',
#          'pluralName': 'Soccer Fields',
#          'shortName': 'Soccer Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c75b662ff1fb60c0422f7a7-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac8c902f964a52090bc20e3',
#        'name': "Rudy's Country Store and Bar-B-Q",
#        'location': {'address': '9828 Dallas Pkwy',
#         'crossStreet': 'Technology Dr',
#         'lat': 33.15988458325843,
#         'lng': -96.83920383453369,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15988458325843,
#           'lng': -96.83920383453369},
#          {'label': 'entrance', 'lat': 33.159824, 'lng': -96.83937}],
#         'distance': 1778,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9828 Dallas Pkwy (Technology Dr)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1883462',
#         'url': 'https://www.grubhub.com/restaurant/rudys-country-store--bbq-9828-dallas-parkway-frisco/1883462?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1883462',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac8c902f964a52090bc20e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '563cd52ccd10f1fc333a8846',
#        'name': 'National Videogame Museum',
#        'location': {'address': '8004 Dallas Pkwy',
#         'lat': 33.14376648804803,
#         'lng': -96.83524909518705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.14376648804803,
#           'lng': -96.83524909518705},
#          {'label': 'entrance', 'lat': 33.145073, 'lng': -96.835162}],
#         'distance': 1329,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8004 Dallas Pkwy',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-563cd52ccd10f1fc333a8846-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c895258055315b20513271',
#        'name': 'Frisco Gun Club',
#        'location': {'address': '6565 Eldorado Pkwy',
#         'crossStreet': 'Tollway at Eldorado',
#         'lat': 33.174174803558586,
#         'lng': -96.82813574943313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.174174803558586,
#           'lng': -96.82813574943313}],
#         'distance': 2649,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6565 Eldorado Pkwy (Tollway at Eldorado)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a11',
#          'name': 'Gun Range',
#          'pluralName': 'Gun Ranges',
#          'shortName': 'Gun Range',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/gun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2054651',
#         'url': 'https://www.grubhub.com/restaurant/frisco-gun-club-dining-6565-w-eldorado-pkwy-frisco/2054651?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2054651',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '72267247'}},
#       'referralId': 'e-0-50c895258055315b20513271-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6beef37d8b2c711b10c31e',
#        'name': 'Costco',
#        'location': {'address': '11220 Dallas Pkwy',
#         'crossStreet': 'at Eldorado Pkwy',
#         'lat': 33.17179069614749,
#         'lng': -96.83732496633725,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.17179069614749,
#           'lng': -96.83732496633725}],
#         'distance': 2675,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11220 Dallas Pkwy (at Eldorado Pkwy)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '52e816a6bcbc57f1066b7a54',
#          'name': 'Warehouse Store',
#          'pluralName': 'Warehouse Stores',
#          'shortName': 'Warehouse Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6beef37d8b2c711b10c31e-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5852bdfc11742042659616b7',
#        'name': 'Starbucks',
#        'location': {'address': '5722 Eldorado Parkway',
#         'lat': 33.175515661692124,
#         'lng': -96.83690177562717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.175515661692124,
#           'lng': -96.83690177562717},
#          {'label': 'entrance', 'lat': 33.175481, 'lng': -96.836738}],
#         'distance': 3029,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5722 Eldorado Parkway',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1631260',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-5722-eldorado-parkway-frisco/1631260?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631260',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5852bdfc11742042659616b7-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '565b3e8b498e3d9d3cd5ed3b',
#        'name': 'Rockfish Seafood Grill',
#        'location': {'lat': 33.154373015732595,
#         'lng': -96.8410762000647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.154373015732595,
#           'lng': -96.8410762000647}],
#         'distance': 1678,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Frisco, TX 75034', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '547164',
#         'url': 'https://www.grubhub.com/restaurant/rockfish-seafood-grill-9179-dallas-parkway-frisco/547164?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=547164',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-565b3e8b498e3d9d3cd5ed3b-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57446c1e498e07be56a4c684',
#        'name': 'Frisco Diner',
#        'location': {'address': '9250 Dallas Pkwy',
#         'lat': 33.15463951448451,
#         'lng': -96.8395151060328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15463951448451,
#           'lng': -96.8395151060328},
#          {'label': 'entrance', 'lat': 33.154623, 'lng': -96.839538}],
#         'distance': 1546,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9250 Dallas Pkwy',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1632643',
#         'url': 'https://www.grubhub.com/restaurant/frisco-diner-9250-dallas-parkway-frisco/1632643?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1632643',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57446c1e498e07be56a4c684-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '526b285311d2a71868713db1',
#        'name': "Eddie's Napolis Ristorante Italiano",
#        'location': {'address': '8822 Teel Pkwy #410',
#         'crossStreet': 'Main St',
#         'lat': 33.15178774993408,
#         'lng': -96.86327283664296,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.15178774993408,
#           'lng': -96.86327283664296},
#          {'label': 'entrance', 'lat': 33.151419, 'lng': -96.863289}],
#         'distance': 3698,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8822 Teel Pkwy #410 (Main St)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1711400',
#         'url': 'https://www.grubhub.com/restaurant/eddies-napolis-8822-teel-pkwy-frisco/1711400?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1711400',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-526b285311d2a71868713db1-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc9e549cc8cd13a3f5fbccf',
#        'name': 'Frisco Athletic Center',
#        'location': {'address': '5828 Nancy Jane Ln',
#         'crossStreet': 'Preston',
#         'lat': 33.12636945002513,
#         'lng': -96.80058372728422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.12636945002513,
#           'lng': -96.80058372728422},
#          {'label': 'entrance', 'lat': 33.126223, 'lng': -96.800652}],
#         'distance': 3453,
#         'postalCode': '75035',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5828 Nancy Jane Ln (Preston)',
#          'Frisco, TX 75035',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc9e549cc8cd13a3f5fbccf-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b65ef01f964a5204f092be3',
#        'name': 'Market Street',
#        'location': {'address': '11999 Dallas Pkwy',
#         'crossStreet': 'at Eldorado Parkway',
#         'lat': 33.176908,
#         'lng': -96.843093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.176908,
#           'lng': -96.843093}],
#         'distance': 3438,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11999 Dallas Pkwy (at Eldorado Parkway)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b65ef01f964a5204f092be3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ec1ed2498e5dcdf03babea',
#        'name': 'The Green Gator',
#        'location': {'address': '5566 Main St Ste 110',
#         'crossStreet': 'Dallas Parkway',
#         'lat': 33.1530052111005,
#         'lng': -96.83863362102139,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.1530052111005,
#           'lng': -96.83863362102139}],
#         'distance': 1423,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5566 Main St Ste 110 (Dallas Parkway)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1077033',
#         'url': 'https://www.grubhub.com/restaurant/the-green-gator-frisco-5566-main-st-ste-110-frisco/1077033?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1077033',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ec1ed2498e5dcdf03babea-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b479bb1f964a520373726e3',
#        'name': 'Kotta Sushi Lounge',
#        'location': {'address': '6959 Lebanon Rd Ste 108',
#         'lat': 33.121950960689716,
#         'lng': -96.82494636580417,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.121950960689716,
#           'lng': -96.82494636580417},
#          {'label': 'entrance', 'lat': 33.122618, 'lng': -96.824949}],
#         'distance': 3199,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6959 Lebanon Rd Ste 108',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1606032',
#         'url': 'https://www.grubhub.com/restaurant/kotta-sushi-lounge-6959-lebanon-road-frisco/1606032?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1606032',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '442248746'}},
#       'referralId': 'e-0-4b479bb1f964a520373726e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527be37211d2138f2849daf4',
#        'name': 'QuikTrip',
#        'location': {'address': '5530 Eldorado Pkwy',
#         'crossStreet': 'Dallas Tollway',
#         'lat': 33.17578632888905,
#         'lng': -96.8384566135664,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 33.175395,
#           'lng': -96.838507},
#          {'label': 'display',
#           'lat': 33.17578632888905,
#           'lng': -96.8384566135664}],
#         'distance': 3118,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5530 Eldorado Pkwy (Dallas Tollway)',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-527be37211d2138f2849daf4-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec2c020b8f7a3b7f969fec9',
#        'name': 'Nothing Bundt Cakes',
#        'location': {'address': '8837 Lebanon Rd Ste 650',
#         'lat': 33.12133509393889,
#         'lng': -96.80740450322213,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.12133509393889,
#           'lng': -96.80740450322213},
#          {'label': 'entrance', 'lat': 33.121325, 'lng': -96.807195}],
#         'distance': 3598,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8837 Lebanon Rd Ste 650',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec2c020b8f7a3b7f969fec9-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be4318dbcef2d7f1e2e02e5',
#        'name': 'Chick-fil-A',
#        'location': {'address': '5211 Eldorado Pkwy',
#         'lat': 33.1744582,
#         'lng': -96.8411861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.1744582,
#           'lng': -96.8411861},
#          {'label': 'entrance', 'lat': 33.174587, 'lng': -96.841166}],
#         'distance': 3113,
#         'postalCode': '75033',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5211 Eldorado Pkwy',
#          'Frisco, TX 75033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be4318dbcef2d7f1e2e02e5-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56d1ea4c498ee9910fa6537b',
#        'name': 'Dallas Cowboys World Headquarers',
#        'location': {'address': '1 Cowboys Way',
#         'crossStreet': 'Gaylord Pkwy.',
#         'lat': 33.10989772199196,
#         'lng': -96.82750166518582,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.10989772199196,
#           'lng': -96.82750166518582}],
#         'distance': 4553,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1 Cowboys Way (Gaylord Pkwy.)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d189941735',
#          'name': 'Football Stadium',
#          'pluralName': 'Football Stadiums',
#          'shortName': 'Football',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_football_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56d1ea4c498ee9910fa6537b-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57bcb455cd107186f3c118a5',
#        'name': 'The Star in Frisco',
#        'location': {'address': 'One Cowboys Way',
#         'crossStreet': 'Gaylord Pkwy.',
#         'lat': 33.109826717709964,
#         'lng': -96.82746677326587,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.109826717709964,
#           'lng': -96.82746677326587}],
#         'distance': 4561,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['One Cowboys Way (Gaylord Pkwy.)',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'shortName': 'Office',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57bcb455cd107186f3c118a5-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '555d30fa498e4fcd3e98642b',
#        'name': 'Blaze Pizza',
#        'location': {'address': '3311 Preston Rd,',
#         'lat': 33.106701,
#         'lng': -96.807703,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.106701,
#           'lng': -96.807703}],
#         'distance': 5114,
#         'postalCode': '75034',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3311 Preston Rd,',
#          'Frisco, TX 75034',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-555d30fa498e4fcd3e98642b-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca23dedb0ff8cfac624ad5e',
#        'name': 'Platia Greek Kouzina',
#        'location': {'address': '1590 Gaylord Pkwy.',
#         'crossStreet': 'at Mall Rd. F',
#         'lat': 33.103939145717696,
#         'lng': -96.80875308986231,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.103939145717696,
#           'lng': -96.80875308986231}],
#         'distance': 5383,
#         'postalCode': '75035',
#         'cc': 'US',
#         'city': 'Frisco',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1590 Gaylord Pkwy. (at Mall Rd. F)',
#          'Frisco, TX 75035',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1631207',
#         'url': 'https://www.grubhub.com/restaurant/platia-greek-kouzina-2995-preston-road-frisco/1631207?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631207',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca23dedb0ff8cfac624ad5e-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
# ...
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e20dc61b0fbdf9ba7a4461d-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcfab4b41b9ef3bb1faf8e5',
#        'name': 'Paciugo Gelato & Caffé',
#        'location': {'address': '7501 Lone Star Dr',
#         'crossStreet': 'Shops at Legacy',
#         'lat': 33.080217665461596,
#         'lng': -96.82294810711302,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.080217665461596,
#           'lng': -96.82294810711302}],
#         'distance': 7843,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['7501 Lone Star Dr (Shops at Legacy)',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcfab4b41b9ef3bb1faf8e5-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbbc9e7e436ef3b75d85564',
#        'name': "Lowe's",
#        'location': {'address': '2773 East Eldorado Parkway',
#         'crossStreet': 'at FM 423',
#         'lat': 33.1800415,
#         'lng': -96.8885896,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.1800415,
#           'lng': -96.8885896}],
#         'distance': 6881,
#         'postalCode': '75068',
#         'cc': 'US',
#         'city': 'Little Elm',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2773 East Eldorado Parkway (at FM 423)',
#          'Little Elm, TX 75068',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112951735',
#          'name': 'Hardware Store',
#          'pluralName': 'Hardware Stores',
#          'shortName': 'Hardware',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbbc9e7e436ef3b75d85564-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a1cbafeb2958f2d80fcc4d4',
#        'name': 'Taverna',
#        'location': {'lat': 33.07967847564921,
#         'lng': -96.82624750755915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.07967847564921,
#           'lng': -96.82624750755915}],
#         'distance': 7907,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Plano, TX 75024', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a1cbafeb2958f2d80fcc4d4-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5400d90c498ef5492ab0f092',
#        'name': 'Hilton',
#        'location': {'address': '5805 Granite Pkwy',
#         'crossStreet': 'at Dallas Pkwy',
#         'lat': 33.088934812639515,
#         'lng': -96.8204015493393,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.088934812639515,
#           'lng': -96.8204015493393}],
#         'distance': 6879,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5805 Granite Pkwy (at Dallas Pkwy)',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5400d90c498ef5492ab0f092-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a7f399e64c8e104232b82ea',
#        'name': 'Bulla Gastrobar',
#        'location': {'address': '6007 Legacy Drive',
#         'lat': 33.07846694,
#         'lng': -96.82736185,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.07846694,
#           'lng': -96.82736185},
#          {'label': 'entrance', 'lat': 33.07825, 'lng': -96.827786}],
#         'distance': 8045,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6007 Legacy Drive',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2038574',
#         'url': 'https://www.grubhub.com/restaurant/bulla-gastrobar--plano-6007-legacy-dr-ste-180-plano/2038574?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2038574',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '560551221'}},
#       'referralId': 'e-0-5a7f399e64c8e104232b82ea-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf5c40e94b2a593b44bacee',
#        'name': "Bob's Steak & Chop House",
#        'location': {'address': '5760 Legacy Dr',
#         'lat': 33.0776378472458,
#         'lng': -96.82041332677198,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.0776378472458,
#           'lng': -96.82041332677198},
#          {'label': 'entrance', 'lat': 33.077518, 'lng': -96.82071}],
#         'distance': 8135,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5760 Legacy Dr',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf5c40e94b2a593b44bacee-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59932647dd84423d0c921f33',
#        'name': 'Tommy Bahama',
#        'location': {'address': '7601 Windrose Ave',
#         'lat': 33.080256857806276,
#         'lng': -96.82619418378194,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.080256857806276,
#           'lng': -96.82619418378194}],
#         'distance': 7842,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['7601 Windrose Ave',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59932647dd84423d0c921f33-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a5fea6c6bdee640564841bd',
#        'name': 'Legacy Hall',
#        'location': {'address': '7800 Windrose Ave',
#         'lat': 33.08329131686857,
#         'lng': -96.82555535136032,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.08329131686857,
#           'lng': -96.82555535136032}],
#         'distance': 7503,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['7800 Windrose Ave',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2034487',
#         'url': 'https://www.grubhub.com/restaurant/dock-local--legacy-hall-7800-windrose-ave-plano/2034487?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2034487',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a5fea6c6bdee640564841bd-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e185783d1648b834830fbf2',
#        'name': "Tiff's Treats",
#        'location': {'address': '5760 State Highway 121 Ste 155',
#         'lat': 33.09077309186784,
#         'lng': -96.8195950542542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.09077309186784,
#           'lng': -96.8195950542542}],
#         'distance': 6678,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5760 State Highway 121 Ste 155',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e185783d1648b834830fbf2-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59c464048d0a537392a48301',
#        'name': 'Starbucks Reserve Bar',
#        'location': {'address': '140 Windrose Ave',
#         'crossStreet': 'Water Street',
#         'lat': 33.08136271918421,
#         'lng': -96.82614500543417,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.08136271918421,
#           'lng': -96.82614500543417}],
#         'distance': 7719,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['140 Windrose Ave (Water Street)',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59c464048d0a537392a48301-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bd35faccb3fd2002d5ba494',
#        'name': "Edith's French Bistro",
#        'location': {'address': '5864 State Hwy 121, Plano, TX 75024',
#         'crossStreet': 'Hwy121 and Dallas North Tollway',
#         'lat': 33.090492,
#         'lng': -96.82027,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.090492,
#           'lng': -96.82027}],
#         'distance': 6706,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5864 State Hwy 121, Plano, TX 75024 (Hwy121 and Dallas North Tollway)',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bd35faccb3fd2002d5ba494-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3bab1ff964a5206b7825e3',
#        'name': 'Potbelly Sandwich Shop',
#        'location': {'address': '5717 Legacy Dr #160',
#         'lat': 33.07846013693692,
#         'lng': -96.81990692429247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.07846013693692,
#           'lng': -96.81990692429247}],
#         'distance': 8046,
#         'postalCode': '75024',
#         'cc': 'US',
#         'city': 'Plano',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5717 Legacy Dr #160',
#          'Plano, TX 75024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1403295',
#         'url': 'https://www.grubhub.com/restaurant/potbelly-sandwich-shop-5717-legacy-dr-ste-160-plano/1403295?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1403295',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3bab1ff964a5206b7825e3-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_Frisco_category_type(row):
    try:
        Frisco_categories_list = row['categories']
    except:
        Frisco_categories_list = row['venue.categories']
        
    if len(Frisco_categories_list) == 0:
        return None
    else:
        return Frisco_categories_list[0]['name']

# %%
Frisco_venues = results1['response']['groups'][0]['items']
    
Frisco_nearby_venues = json_normalize(Frisco_venues) # flatten JSON

# filter columns
Frisco_filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
Frisco_nearby_venues =Frisco_nearby_venues.loc[:, Frisco_filtered_columns]

# filter the category for each row
Frisco_nearby_venues['venue.categories'] = Frisco_nearby_venues.apply(get_Frisco_category_type, axis=1)

# clean columns
Frisco_nearby_venues.columns = [col.split(".")[-1] for col in Frisco_nearby_venues.columns]

Frisco_nearby_venues.head()
# Out:
#                           name                       categories        lat  \
# 0  Babe's Chicken Dinner House  Southern / Soul Food Restaurant  33.149031
# 1          Mariana's Taco Shop               Mexican Restaurant  33.151367
# 2        Frisco Public Library                          Library  33.150182
# 3               Frisco Commons                             Park  33.153426
# 4        5th Street Patio Cafe              American Restaurant  33.147813
#
#          lng
# 0 -96.830446
# 1 -96.824001
# 2 -96.834209
# 3 -96.813934
# 4 -96.824797

# %%
print('{} venues were returned by Foursquare.'.format(Frisco_nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %%
#sorted by the count in decending order to get top 15
LE_grouped = nearby_venues.groupby('categories').count().reset_index()
LE_grouped.sort_values(by=['name'],inplace=True, ascending=False)
LE_grouped.head(15)
# Out:
#               categories  name  lat  lng
# 11  Fast Food Restaurant    10   10   10
# 22    Mexican Restaurant     5    5    5
# 25           Pizza Place     5    5    5
# 29        Sandwich Place     4    4    4
# 0    American Restaurant     4    4    4
# 7      Convenience Store     3    3    3
# 9         Discount Store     3    3    3
# 3           Burger Joint     3    3    3
# 24              Pharmacy     3    3    3
# 14   Fried Chicken Joint     3    3    3
# 21                  Lake     2    2    2
# 26                  Pool     2    2    2
# 19          Home Service     2    2    2
# 4                   Café     2    2    2
# 23                  Park     1    1    1

# %%
LE_grouped = nearby_venues.groupby('categories').count().reset_index()
LE_grouped.sort_values(by=['name'],inplace=True)
LE_grouped.head(10)
# Out:
#                                   categories  name  lat  lng
# 17                             Grocery Store     1    1    1
# 33                                Taco Place     1    1    1
# 32                                Sports Bar     1    1    1
# 31                             Smoothie Shop     1    1    1
# 30                            Shipping Store     1    1    1
# 28                                Restaurant     1    1    1
# 27  Residential Building (Apartment / Condo)     1    1    1
# 23                                      Park     1    1    1
# 20                        Italian Restaurant     1    1    1
# 18                      Gym / Fitness Center     1    1    1

# %%
#sorted by the count in decending order to get top 15
Frisco_grouped = Frisco_nearby_venues.groupby('categories').count().reset_index()
Frisco_grouped.sort_values(by=['name'],inplace=True,ascending=False)
Frisco_grouped.head(15)
# Out:
#               categories  name  lat  lng
# 37    Mexican Restaurant     5    5    5
# 11           Coffee Shop     5    5    5
# 31    Italian Restaurant     4    4    4
# 0    American Restaurant     4    4    4
# 27  Gym / Fitness Center     3    3    3
# 60      Sushi Restaurant     3    3    3
# 58            Steakhouse     3    3    3
# 16  Fast Food Restaurant     3    3    3
# 30        Ice Cream Shop     3    3    3
# 55   Sporting Goods Shop     2    2    2
# 8           Burger Joint     2    2    2
# 59           Supermarket     2    2    2
# 35        Lingerie Store     2    2    2
# 41                  Park     2    2    2
# 1              BBQ Joint     2    2    2

# %%
Frisco_grouped = Frisco_nearby_venues.groupby('categories').count().reset_index()
Frisco_grouped.sort_values(by=['name'],inplace=True)
Frisco_grouped.head(10)
# Out:
#                    categories  name  lat  lng
# 32          Korean Restaurant     1    1    1
# 64            Warehouse Store     1    1    1
# 33  Latin American Restaurant     1    1    1
# 34                    Library     1    1    1
# 36               Liquor Store     1    1    1
# 38                     Museum     1    1    1
# 39    New American Restaurant     1    1    1
# 40                     Office     1    1    1
# 43                 Playground     1    1    1
# 44                        Pub     1    1    1

# %% [markdown]
# Based on the Top 10 Categories in Frisco, and the bottom 10 Categories in Aubrey, there are a lot of business opportunities and selections to choose from.

# %%
i have decided that opening business in the following cagetories could be promising: Ice Cream Stop, fast foods, Furniture / Home Store I might be willing to consider a place like a Coffee Shop,
but on a more cautious basis.
